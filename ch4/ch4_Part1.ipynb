# %% [markdown]
# # Data Collection - Part1

# %% [markdown]
# ## Load needed Libraries and modules

# %%
# import Libs
import pandas as pd
import datetime as dt
import pytz
import os
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf

# import modules
from datetime import datetime, timezone
from datetime import date, time
from math import trunc
from dateutil.parser import parse

# %% [markdown]
# ## Collecting Options Data from Yahoo Finance using "yfinance"

# %% [markdown]
# ### Getting AAPL underlying stock prices

# %%
# Define the ticker symbol
tickerSymbol = 'AAPL'

# Get data on this ticker
tickerData = yf.Ticker(tickerSymbol)

# Get the historical prices for this ticker
mb_tickerdf04152024 = tickerData.history(period='5y')

# See the data
mb_tickerdf04152024
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2019-04-15 00:00:00-04:00   47.793186   48.098844   47.656000   47.949623
# 2019-04-16 00:00:00-04:00   48.004988   48.464674   47.788379   47.954445
# 2019-04-17 00:00:00-04:00   48.024227   48.948421   47.800402   48.888252
# 2019-04-18 00:00:00-04:00   48.885853   49.133747   48.741450   49.063953
# 2019-04-22 00:00:00-04:00   48.816066   49.323890   48.698134   49.225212
# ...                               ...         ...         ...         ...
# 2024-04-09 00:00:00-04:00  168.699997  170.080002  168.350006  169.669998
# 2024-04-10 00:00:00-04:00  168.800003  169.089996  167.110001  167.779999
# 2024-04-11 00:00:00-04:00  168.339996  175.460007  168.160004  175.039993
# 2024-04-12 00:00:00-04:00  174.259995  178.360001  174.210007  176.550003
# 2024-04-15 00:00:00-04:00  175.380005  175.979904  173.850006  174.309998
#
#                               Volume  Dividends  Stock Splits
# Date
# 2019-04-15 00:00:00-04:00   70146400        0.0           0.0
# 2019-04-16 00:00:00-04:00  102785600        0.0           0.0
# 2019-04-17 00:00:00-04:00  115627200        0.0           0.0
# 2019-04-18 00:00:00-04:00   96783200        0.0           0.0
# 2019-04-22 00:00:00-04:00   77758000        0.0           0.0
# ...                              ...        ...           ...
# 2024-04-09 00:00:00-04:00   42451200        0.0           0.0
# 2024-04-10 00:00:00-04:00   49709300        0.0           0.0
# 2024-04-11 00:00:00-04:00   91070300        0.0           0.0
# 2024-04-12 00:00:00-04:00  101593300        0.0           0.0
# 2024-04-15 00:00:00-04:00    6930960        0.0           0.0
#
# [1259 rows x 7 columns]

# %%
mb_tickerdf04152024.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1259 entries, 2019-04-15 00:00:00-04:00 to 2024-04-15 00:00:00-04:00
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          1259 non-null   float64
#  1   High          1259 non-null   float64
#  2   Low           1259 non-null   float64
#  3   Close         1259 non-null   float64
#  4   Volume        1259 non-null   int64
#  5   Dividends     1259 non-null   float64
#  6   Stock Splits  1259 non-null   float64
# dtypes: float64(6), int64(1)
# memory usage: 78.7 KB

# %% [markdown]
# ### Saving the Stock Prices dataframe into a csv file

# %%
# get current date and time
current_datetime = datetime.now()
print("Current date & time : ", current_datetime)
filename1 = datetime.now().strftime("%Y-%m-%d %H-%M-%S-%f")

# create a file object along with extension
file_name = "mb_tickerdf04152024 "+filename1+".csv"
#print (file_name)

# converting to csv
mb_tickerdf04152024.to_csv(file_name)
print("~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~")
print("File saved named:")
print (file_name)
print(current_datetime)    
print("~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~")
# Out:
# Current date & time :  2024-04-15 09:39:43.558192
# ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~
# File saved named:
# mb_tickerdf04152024 2024-04-15 09-39-43-558192.csv
# 2024-04-15 09:39:43.558192
# ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~

# %% [markdown]
# ### Getting AAPL stock Options related data including Implied Volatilities

# %%
# Define the ticker symbol
tickerSymbol = 'AAPL'

# Get data on this ticker
tickerData = yf.Ticker(tickerSymbol)

# Get the option expirations
options_expirations = tickerData.options

# Prepare a list to hold all options data
options_list = []

# Loop through each options expiration date
for expiration in options_expirations:
    # Get options data for each expiration date
    options_data = tickerData.option_chain(expiration)
    
    # Add option type and expiration date to the data
    options_data.calls['OptionType'] = 'Call'
    options_data.calls['expirationDate'] = expiration
    options_data.puts['OptionType'] = 'Put'
    options_data.puts['expirationDate'] = expiration
    
    # Append the data to the options_list
    options_list.append(options_data.calls)
    options_list.append(options_data.puts)

# Concatenate all options data into a single DataFrame
mb_all_options_data04152024 = pd.concat(options_list)

# Reset the index and drop the old one
mb_all_options_data04152024.reset_index(drop=True, inplace=True)

# Convert the expirationDate column to datetime
mb_all_options_data04152024['expirationDate'] = pd.to_datetime(mb_all_options_data04152024['expirationDate'])

# Calculate the time to expiration in days
mb_all_options_data04152024['time_to_expiration'] = (mb_all_options_data04152024['expirationDate'] - datetime.now()).dt.days

# Display the DataFrame
mb_all_options_data04152024
# Out:
#            contractSymbol             lastTradeDate  strike  lastPrice  bid  \
# 0     AAPL240419C00005000 2024-04-12 13:51:51+00:00     5.0     173.00  0.0
# 1     AAPL240419C00010000 2024-03-27 19:35:59+00:00    10.0     163.00  0.0
# 2     AAPL240419C00015000 2024-04-04 14:55:59+00:00    15.0     155.95  0.0
# 3     AAPL240419C00030000 2024-03-27 15:14:12+00:00    30.0     142.65  0.0
# 4     AAPL240419C00035000 2024-04-12 14:02:42+00:00    35.0     142.43  0.0
# ...                   ...                       ...     ...        ...  ...
# 1910  AAPL261218P00210000 2024-04-12 17:59:06+00:00   210.0      39.98  0.0
# 1911  AAPL261218P00220000 2024-04-11 19:36:50+00:00   220.0      46.72  0.0
# 1912  AAPL261218P00230000 2024-04-11 17:17:27+00:00   230.0      58.15  0.0
# 1913  AAPL261218P00280000 2024-04-11 18:22:04+00:00   280.0     106.00  0.0
# 1914  AAPL261218P00350000 2024-04-10 13:38:45+00:00   350.0     181.24  0.0
#
#       ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0     0.0     0.0            0.0     1.0           655            0.00001
# 1     0.0     0.0            0.0    20.0            11            0.00001
# 2     0.0     0.0            0.0     1.0             2            0.00001
# 3     0.0     0.0            0.0    30.0            45            0.00001
# 4     0.0     0.0            0.0    12.0             3            0.00001
# ...   ...     ...            ...     ...           ...                ...
# 1910  0.0     0.0            0.0     3.0             5            0.00001
# 1911  0.0     0.0            0.0     2.0             3            0.00001
# 1912  0.0     0.0            0.0     2.0             3            0.00001
# 1913  0.0     0.0            0.0     NaN             1            0.00001
# 1914  0.0     0.0            0.0     NaN             0            0.00001
#
#       inTheMoney contractSize currency OptionType expirationDate  \
# 0           True      REGULAR      USD       Call     2024-04-19
# 1           True      REGULAR      USD       Call     2024-04-19
# 2           True      REGULAR      USD       Call     2024-04-19
# 3           True      REGULAR      USD       Call     2024-04-19
# 4           True      REGULAR      USD       Call     2024-04-19
# ...          ...          ...      ...        ...            ...
# 1910        True      REGULAR      USD        Put     2026-12-18
# 1911        True      REGULAR      USD        Put     2026-12-18
# 1912        True      REGULAR      USD        Put     2026-12-18
# 1913        True      REGULAR      USD        Put     2026-12-18
# 1914        True      REGULAR      USD        Put     2026-12-18
#
#       time_to_expiration
# 0                      3
# 1                      3
# 2                      3
# 3                      3
# 4                      3
# ...                  ...
# 1910                 976
# 1911                 976
# 1912                 976
# 1913                 976
# 1914                 976
#
# [1915 rows x 17 columns]

# %%
mb_all_options_data04152024.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1915 entries, 0 to 1914
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   contractSymbol      1915 non-null   object
#  1   lastTradeDate       1915 non-null   datetime64[ns, UTC]
#  2   strike              1915 non-null   float64
#  3   lastPrice           1915 non-null   float64
#  4   bid                 1915 non-null   float64
#  5   ask                 1915 non-null   float64
#  6   change              1915 non-null   float64
#  7   percentChange       1915 non-null   float64
#  8   volume              1848 non-null   float64
#  9   openInterest        1915 non-null   int64
#  10  impliedVolatility   1915 non-null   float64
#  11  inTheMoney          1915 non-null   bool
#  12  contractSize        1915 non-null   object
#  13  currency            1915 non-null   object
#  14  OptionType          1915 non-null   object
#  15  expirationDate      1915 non-null   datetime64[ns]
#  16  time_to_expiration  1915 non-null   int64
# dtypes: bool(1), datetime64[ns, UTC](1), datetime64[ns](1), float64(8), int64(2), object(4)
# memory usage: 241.4+ KB

# %%
mb_all_options_data04152024.describe().transpose()
# Out:
#                      count                           mean  \
# strike              1915.0                     167.973629
# lastPrice           1915.0                      29.221906
# bid                 1915.0                       7.560392
# ask                 1915.0                       7.764888
# change              1915.0                            0.0
# percentChange       1915.0                            0.0
# volume              1848.0                     795.719697
# openInterest        1915.0                    3317.779112
# impliedVolatility   1915.0                       0.141293
# expirationDate        1915  2025-01-23 05:04:32.584856064
# time_to_expiration  1915.0                     282.211488
#
#                                     min                  25%  \
# strike                              5.0                115.0
# lastPrice                          0.01                  0.4
# bid                                 0.0                  0.0
# ask                                 0.0                  0.0
# change                              0.0                  0.0
# percentChange                       0.0                  0.0
# volume                              1.0                  2.0
# openInterest                        0.0                 38.0
# impliedVolatility               0.00001              0.00001
# expirationDate      2024-04-19 00:00:00  2024-06-21 00:00:00
# time_to_expiration                  3.0                 66.0
#
#                                     50%                  75%  \
# strike                            165.0                220.0
# lastPrice                           9.4               47.225
# bid                                 0.0                  0.0
# ask                                 0.0                  0.0
# change                              0.0                  0.0
# percentChange                       0.0                  0.0
# volume                             12.0               104.25
# openInterest                      442.0               2387.0
# impliedVolatility               0.03126             0.125009
# expirationDate      2024-11-15 00:00:00  2025-06-20 00:00:00
# time_to_expiration                213.0                430.0
#
#                                     max          std
# strike                            380.0    74.381553
# lastPrice                         187.0    39.024483
# bid                               195.7    26.319461
# ask                              199.15    26.948647
# change                              0.0          0.0
# percentChange                       0.0          0.0
# volume                         150833.0  5857.506331
# openInterest                    82242.0  7935.967153
# impliedVolatility             10.823245     0.492238
# expirationDate      2026-12-18 00:00:00          NaN
# time_to_expiration                976.0   268.502375

# %% [markdown]
# ### Saving Options Information dataframe into a csv file

# %%
# get current date and time
current_datetime = datetime.now()
print("Current date & time : ", current_datetime)
filename1 = datetime.now().strftime("%Y-%m-%d %H-%M-%S-%f")

# create a file object along with extension
file_name = "mb_all_options_data04152024 "+filename1+".csv"
#print (file_name)

# converting to csv
mb_all_options_data04152024.to_csv(file_name)
print("~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~")
print("File saved named:")
print (file_name)
print(current_datetime)    
print("~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~")
# Out:
# Current date & time :  2024-04-15 09:39:46.199775
# ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~
# File saved named:
# mb_all_options_data04152024 2024-04-15 09-39-46-200765.csv
# 2024-04-15 09:39:46.199775
# ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~

# %% [markdown]
# ### Getting Interest Rate Data

# %%
mb_US_T_04152024 = pd.read_csv("US_Treasury_04152024.csv")
mb_US_T_04152024
# Out:
#    US_Treasury_Rates  Yield
# 0                 1m   5.48
# 1                 2m   5.50
# 2                 3m   5.45
# 3                 4m   5.42
# 4                 6m   5.36
# 5                 1y   5.13
# 6                 2y   4.88
# 7                 3y   4.70
# 8                 5y   4.54
# 9                 7y   4.53
# 10               10y   4.50
# 11               20y   4.73
# 12               30y   4.61

# %% [markdown]
# ### Saving the Interest Rate dataframe into a csv file

# %%
# get current date and time
current_datetime = datetime.now()
print("Current date & time : ", current_datetime)
filename1 = datetime.now().strftime("%Y-%m-%d %H-%M-%S-%f")

# create a file object along with extension
file_name = "mb_US_T_04152024 "+filename1+".csv"
#print (file_name)

# converting to csv
mb_US_T_04152024.to_csv(file_name)
print("~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~")
print("File saved named:")
print (file_name)
print(current_datetime)    
print("~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~")
# Out:
# Current date & time :  2024-04-15 09:39:46.240619
# ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~
# File saved named:
# mb_US_T_04152024 2024-04-15 09-39-46-240619.csv
# 2024-04-15 09:39:46.240619
# ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~ ~~~~
