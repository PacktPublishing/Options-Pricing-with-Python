# %% [markdown]
# ***
# # *Options Strategies, Portfolio Optimization and Risk Management*
# ***

# %% [markdown]
# ## Load the Libs we need

# %%
# imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as si
from scipy.optimize import minimize

# %% [markdown]
# ## Introduction to Portfolio Optimization and Risk Management

# %%
# Suppose we have two AAPL options with the following expected returns and standard deviations:
# Option1: Expected Return = 0.08, Standard Deviation = 0.2
# Option2: Expected Return = 0.12, Standard Deviation = 0.3

# Portfolio weights (50% in each option)
weights = np.array([0.5, 0.5])

# Expected returns and standard deviations
returns = np.array([0.08, 0.12])
std_devs = np.array([0.2, 0.3])

# Calculate portfolio expected return and standard deviation
port_return = np.dot(weights, returns)
port_std_dev = np.sqrt(np.dot(weights**2, std_devs**2))

print(f"Portfolio Expected Return: {port_return:.2f}")
print(f"Portfolio Standard Deviation: {port_std_dev:.2f}")
# Out:
# Portfolio Expected Return: 0.10
# Portfolio Standard Deviation: 0.18

# %%
# Sample returns and covariance matrix for two AAPL options
returns = np.array([0.08, 0.12])
cov_matrix = np.array([[0.04, 0.02], [0.02, 0.09]])  # Assuming some covariance between the options

def mb_negative_sharpe(weights): 
    port_return = np.dot(weights, returns)
    port_volatility = np.sqrt(np.dot(weights.T, np.dot(cov_matrix, weights)))
    return -port_return / port_volatility

# Constraints and bounds
cons = ({'type': 'eq', 'fun': lambda weights: np.sum(weights) - 1}) 
bounds = ((0, 1), (0, 1))
initial_weights = [0.5, 0.5]

solution = minimize(mb_negative_sharpe, initial_weights, method='SLSQP', bounds=bounds, constraints=cons)
optimal_weights = solution.x

print(f"Optimal Weights: {optimal_weights}")
# Out:
# Optimal Weights: [0.59920317 0.40079683]

# %% [markdown]
# ## Diversification and Modern Portfolio Theory in Options Trading

# %%
# Assuming a correlation of -0.5 between the two options
correlation = -0.5
covariance = correlation * std_devs[0] * std_devs[1]

# Portfolio variance formula considering covariance
port_variance = weights[0]**2 * std_devs[0]**2 + weights[1]**2 * std_devs[1]**2 + 2 * weights[0] * weights[1] * covariance
port_std_dev_diversified = np.sqrt(port_variance)

print(f"Portfolio Standard Deviation with Diversification: {port_std_dev_diversified:.2f}")
# Out:
# Portfolio Standard Deviation with Diversification: 0.13

# %%
num_portfolios = 10000
results = np.zeros((3, num_portfolios))
for i in range(num_portfolios):
    weights = np.random.random(2)
    weights /= np.sum(weights)
    
    port_return = np.dot(weights, returns)
    port_volatility = np.sqrt(np.dot(weights.T, np.dot(cov_matrix, weights)))
    results[0,i] = port_return
    results[1,i] = port_volatility
    results[2,i] = results[0,i] / results[1,i]  # Sharpe Ratio

# Plotting
plt.scatter(results[1,:], results[0,:], c=results[2,:], cmap='YlGnBu', marker='o')
plt.title('Efficient Frontier with AAPL Options')
plt.xlabel('Portfolio Volatility')
plt.ylabel('Portfolio Return')
plt.colorbar(label='Sharpe Ratio')
plt.show()

# %% [markdown]
# ## Constructing Efficient Portfolios with Python

# %%
# For simplicity, let's assume we already have a dataframe with AAPL options data
# df_options = pd.read_csv('AAPL_options_data.csv')

# Sample DataFrame (Replace this with actual data)
data = {
    'Option': ['AAPL_Call_150', 'AAPL_Put_140'],
    'Price': [10, 8],
    'Expected_Return': [0.08, 0.12]
}
df_options = pd.DataFrame(data)

# Create a portfolio with equal weight to each option
df_options['Weight'] = 0.5

# Calculate portfolio cost
df_options['Investment'] = df_options['Weight'] * df_options['Price']
portfolio_cost = df_options['Investment'].sum()

print(df_options)
print(f"Total Portfolio Cost: ${portfolio_cost}")
# Out:
#           Option  Price  Expected_Return  Weight  Investment
# 0  AAPL_Call_150     10             0.08     0.5         5.0
# 1   AAPL_Put_140      8             0.12     0.5         4.0
# Total Portfolio Cost: $9.0

# %%
# Mocking a dataset of AAPL options with historical returns
data = {
    'AAPL_Call_150': [0.02, 0.03, 0.04, 0.03, 0.05],
    'AAPL_Put_140': [-0.01, -0.02, 0.02, 0.03, 0.01],
    'AAPL_Call_155': [0.04, 0.05, 0.06, 0.07, 0.08]
}
df = pd.DataFrame(data)

# Calculate mean returns and covariance matrix
mean_returns = df.mean()
cov_matrix = df.cov()

# Objective function to maximize the Sharpe Ratio
def mb_negative_sharpe(weights): 
    port_return = np.dot(weights, mean_returns)
    port_volatility = np.sqrt(np.dot(weights.T, np.dot(cov_matrix, weights)))
    return -port_return / port_volatility

# Constraints and bounds for three assets
cons = ({'type': 'eq', 'fun': lambda weights: np.sum(weights) - 1}) 
bounds = ((0, 1), (0, 1), (0, 1))
initial_weights = [1/3, 1/3, 1/3]

# Optimization to find the optimal weights
solution = minimize(mb_negative_sharpe, initial_weights, method='SLSQP', bounds=bounds, constraints=cons)
optimal_weights = solution.x

print(f"Optimal Weights: {optimal_weights}")

# Visualize Efficient Frontier
portfolio_returns = []
portfolio_volatilities = []
for _ in range(10000):
    weights = np.random.random(3)
    weights /= np.sum(weights)
    
    port_return = np.dot(weights, mean_returns)
    port_vol = np.sqrt(np.dot(weights.T, np.dot(cov_matrix, weights)))
    
    portfolio_returns.append(port_return)
    portfolio_volatilities.append(port_vol)

plt.scatter(portfolio_volatilities, portfolio_returns, c=[r/v for r, v in zip(portfolio_returns, portfolio_volatilities)], cmap='YlGnBu', marker='o')
plt.title('Efficient Frontier of AAPL Options Portfolio')
plt.xlabel('Portfolio Volatility')
plt.ylabel('Portfolio Return')
plt.colorbar(label='Sharpe Ratio')
plt.show()
# Out:
# Optimal Weights: [4.16333634e-17 4.68375339e-16 1.00000000e+00]

# %% [markdown]
# ## Options Strategies and Risk Management Techniques in Options Trading

# %% [markdown]
# ### Implementing Simple Protective Measures with Options

# %% [markdown]
# #### Protective Puts

# %%
# Parameters
stock_price = 100  # Current stock price
strike_price = 95  # Put option strike price
premium_put = 3    # Cost of the put option

def mb_protective_put_payoff(s):
    return max(strike_price - s, 0) - premium_put + (s - stock_price)

stock_prices = np.arange(80, 120, 1)
payoffs = [mb_protective_put_payoff(s) for s in stock_prices]

plt.plot(stock_prices, payoffs)
plt.title('Protective Put Payoff')
plt.xlabel('Stock Price at Expiry')
plt.ylabel('Profit/Loss')
plt.grid(True)
plt.show()

# %% [markdown]
# #### Covered Calls

# %%
# Parameters for Covered Call
strike_price_call = 110  # Call option strike price
premium_call = 5         # Income received from selling the call

def mb_covered_call_payoff(s):
    return (s - stock_price) - max(s - strike_price_call, 0) + premium_call

payoffs = [mb_covered_call_payoff(s) for s in stock_prices]

plt.plot(stock_prices, payoffs)
plt.title('Covered Call Payoff')
plt.xlabel('Stock Price at Expiry')
plt.ylabel('Profit/Loss')
plt.grid(True)
plt.show()

# %% [markdown]
# #### Collars

# %%
# Parameters for Collar
premium_put = 4
premium_call = 4
strike_price_put = 95
strike_price_call = 110

def mb_collar_payoff(s):
    put_component = max(strike_price_put - s, 0)
    call_component = max(s - strike_price_call, 0)

    return (
        (s - stock_price)
        + put_component
        - call_component
        + premium_call
        - premium_put
    )

payoffs = [mb_collar_payoff(s) for s in stock_prices]

plt.plot(stock_prices, payoffs)
plt.title('Collar Strategy Payoff')
plt.xlabel('Stock Price at Expiry')
plt.ylabel('Profit/Loss')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Exploring Advanced Options Risk Management Strategies

# %% [markdown]
# #### Iron Condors

# %%
# Parameters for Iron Condor
lower_strike_put = 95
upper_strike_put = 100
lower_strike_call = 105
upper_strike_call = 110

premium_sold = 6
premium_bought = 2

def mb_iron_condor_payoff(s):
    long_put = max(lower_strike_put - s, 0)
    short_put = -max(upper_strike_put - s, 0)
    short_call = -max(s - lower_strike_call, 0)
    long_call = max(s - upper_strike_call, 0)

    net_credit = premium_sold - premium_bought

    return long_put + short_put + short_call + long_call + net_credit

stock_prices = np.arange(90, 115, 1)
payoffs = [mb_iron_condor_payoff(s) for s in stock_prices]

plt.plot(stock_prices, payoffs)
plt.title('Iron Condor Payoff')
plt.xlabel('Stock Price at Expiry')
plt.ylabel('Profit/Loss')
plt.grid(True)
plt.show()

# %% [markdown]
# #### Straddles

# %%
# Parameters for Straddle
strike_price = 100
premium = 12  # Total premium paid for both the call and put

def mb_straddle_payoff(s):
    return max(s - strike_price, 0) + max(strike_price - s, 0) - premium

payoffs = [mb_straddle_payoff(s) for s in stock_prices]

plt.plot(stock_prices, payoffs)
plt.title('Long Straddle Payoff')
plt.xlabel('Stock Price at Expiry')
plt.ylabel('Profit/Loss')
plt.grid(True)
plt.show()

# %% [markdown]
# #### Strangles

# %%
# Parameters for Strangle
lower_strike = 95
upper_strike = 105
premium = 10  # Total premium paid

def mb_strangle_payoff(s):
    return max(s - upper_strike, 0) + max(lower_strike - s, 0) - premium

payoffs = [mb_strangle_payoff(s) for s in stock_prices]

plt.plot(stock_prices, payoffs)
plt.title('Long Strangle Payoff')
plt.xlabel('Stock Price at Expiry')
plt.ylabel('Profit/Loss')
plt.grid(True)
plt.show()

# %% [markdown]
# #### Bull Spreads

# %%
# Parameters for Bull Spread
lower_strike = 100
upper_strike = 105
premium_lower = 8
premium_upper = 4

def mb_bull_spread_payoff(s):
    return max(s - lower_strike, 0) - premium_lower + premium_upper - max(s - upper_strike, 0)

payoffs = [mb_bull_spread_payoff(s) for s in stock_prices]

plt.plot(stock_prices, payoffs)
plt.title('Bull Spread Payoff')
plt.xlabel('Stock Price at Expiry')
plt.ylabel('Profit/Loss')
plt.grid(True)
plt.show()

# %% [markdown]
# #### Bear Spreads

# %%
# Parameters for Bear Spread
higher_strike = 105
lower_strike = 100
premium_higher = 8
premium_lower = 4

def mb_bear_spread_payoff(s):
    return max(higher_strike - s, 0) - premium_higher + premium_lower - max(lower_strike - s, 0)

payoffs = [mb_bear_spread_payoff(s) for s in stock_prices]

plt.plot(stock_prices, payoffs)
plt.title('Bear Spread Payoff')
plt.xlabel('Stock Price at Expiry')
plt.ylabel('Profit/Loss')
plt.grid(True)
plt.show()

# %% [markdown]
# #### Butterfly Spreads

# %%
# Parameters for Butterfly Spread
lower_strike = 95
middle_strike = 100
upper_strike = 105
premium_lower = 9
premium_middle = 5
premium_upper = 2

def mb_butterfly_payoff(s):
    return (max(s - lower_strike, 0) - 2 * max(s - middle_strike, 0) + max(s - upper_strike, 0) -
            premium_lower + 2 * premium_middle - premium_upper)

payoffs = [mb_butterfly_payoff(s) for s in stock_prices]

plt.plot(stock_prices, payoffs)
plt.title('Butterfly Spread Payoff')
plt.xlabel('Stock Price at Expiry')
plt.ylabel('Profit/Loss')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Integrating Risk Management into Trading Strategies

# %% [markdown]
# ##### A simplified illustrative VaR example

# %%
# Parametric VaR example
confidence_level = 0.95

# Define the portfolio inputs explicitly so this cell is self-contained
portfolio_expected_return = 0.10
portfolio_std_dev = np.sqrt(
    0.5**2 * 0.2**2 +
    0.5**2 * 0.3**2
)

# VaR reported as a positive loss magnitude
VaR_95 = (
    si.norm.ppf(confidence_level) * portfolio_std_dev
    - portfolio_expected_return
)

print(f"Value at Risk at 95% Confidence Level: {VaR_95:.2%}")
# Out:
# Value at Risk at 95% Confidence Level: 19.65%

# %%
np.random.seed(42)  # for reproducibility

# Mock returns and covariance matrix for three AAPL options
returns = np.array([0.08, 0.12, 0.07])
cov_matrix = np.array([[0.04, 0.02, 0.01], 
                       [0.02, 0.09, 0.03], 
                       [0.01, 0.03, 0.05]]) 

# Objective function to maximize the Sharpe Ratio
def mb_negative_sharpe(weights): 
    port_return = np.dot(weights, returns)
    port_volatility = np.sqrt(np.dot(weights.T, np.dot(cov_matrix, weights)))
    return -port_return / port_volatility

# Constraints and bounds for three options
cons = ({'type': 'eq', 'fun': lambda weights: np.sum(weights) - 1}) 
bounds = ((0, 1), (0, 1), (0, 1))
initial_weights = [1/3, 1/3, 1/3]  # Evenly distributed for the start

# Optimization
solution = minimize(mb_negative_sharpe, initial_weights, method='SLSQP', bounds=bounds, constraints=cons)
optimal_weights = solution.x

# Monte Carlo Simulation for VaR
num_simulations = 10000
simulation_results = np.zeros(num_simulations)

for i in range(num_simulations):
    random_returns = np.random.multivariate_normal(returns, cov_matrix)
    portfolio_return = np.dot(optimal_weights, random_returns)
    simulation_results[i] = portfolio_return

VaR_95 = -np.percentile(simulation_results, 5)

print(f"Value at Risk (VaR) at 95% Confidence Level: {VaR_95:.2%}")
# Out:
# Value at Risk (VaR) at 95% Confidence Level: 19.88%
